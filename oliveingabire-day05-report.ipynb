# %% [markdown]
#  ### My  first `Git repository`  with basic `commands`

# %% [markdown]
# highe@LAPTOP-J3MS517U MINGW64 ~/simplestats (master)
# $ history
#
#   400  man git
#   401  git help
#   402  q
#   403  git config --global user.email "olive.ingabire@aims.ac.rw"
#   404  git config -- global user.name "Olive INGABIRE"
#   405  git config -- global user.name "oliveingabire"
#   406  git config list
#   407  git config --global user.name "oliveingabire"
#   408  git config list
#   409  git init
#   410  cd
#   411  ls
#   412  rm -rf .git
#   413  cd
#   414  mkdir simplestats
#   415  cd simplestats
#   416  git init
#   417  ls
#   418  ls -A .git
#   419  cd .git
#   420  ls -A
#   421  nano description
#   422  git status
#   423  tree
#   424  tree
#   425  tree
#   426  cd ..
#   427  git status
#   428  touch README.md
#   429  git status
#   430  git commit -am "This is the first commit. It adds a readme file."
#   431  git add README.md
#   432  git status
#   433  git commit -am "This is the first commit. It adds a readme file."
#   434  git status
#   435  pwd
#   436  diff file1.txt file2.txt
#   437  diff file1.txt file2.txt
#   438  diff file1.txt file2.txt
#   439  git diff
#   440  git diff --stat
#   441  git diff HEAD --cached
#   442  git log
#   443  git reset temp_notes
#   444  git status
#   445  git reset temp_notes.txt
#   446  git status
#   447  git reset temp_notes
#   448  git reset temp_notes.txt
#   449  git status
#   450  nano README.md
#   451  git checkout -- README.md
#   452  git status
#   453  cat README.md
#   454  nano README.md
#   455  git status
#   456  git checkout -- README.md
#   457  git status
#   458  nano READYOU.md
#   459  git status
#   460  git rm READYOU.md
#   461  git status
#   462  git rm READYOU.md
#   463  git status
#   464  history
#   465  Desktop
#   466  cd Desktop
#   467  cd ..
#   468  cd simplstats
#   469  cd simplestats
#   470  history
#
# highe@LAPTOP-J3MS517U MINGW64 ~/simplestats (master)
# $
